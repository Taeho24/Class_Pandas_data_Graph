# %%
# pandas
import pandas as pd
import matplotlib.pyplot as plt

df2 = pd.read_excel('./한국전력공사_지역별 전기차 충전기 현황정보_20221231.xlsx')
df3 = pd.read_excel('./한국전력공사_지역별 전기차 충전소 현황정보_20230718.xlsx')

df= df2+df3
print(df.head())
df.plot()
# Out:
#    2016  2017  2018  2019  2020  2021  2022  2023          지역
# 0    30   281   376   418   532   579   NaN   NaN      강원도강원도
# 1   162  1307  2270  2433  2783  2956   NaN   NaN      경기도경기도
# 2   132   447   726   795   985  1124   NaN   NaN    경상남도경상남도
# 3    55   329   488   576   677   838   NaN   NaN    경상북도경상북도
# 4    29   122   208   242   307   349   NaN   NaN  광주광역시광주광역시
